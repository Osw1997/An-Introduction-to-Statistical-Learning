# %% [markdown]
# <a href="https://colab.research.google.com/github/Osw1997/An-Introduction-to-Statistical-Learning/blob/main/Chapter_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Introduction To Statistical Learning (ITSL)
# ##Capítulo 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
colleges = pd.read_csv('drive/MyDrive/itsl_datasets/College.csv')
colleges
# Out:
#                          Unnamed: 0 Private  ...  Expend  Grad.Rate
# 0      Abilene Christian University     Yes  ...    7041         60
# 1                Adelphi University     Yes  ...   10527         56
# 2                    Adrian College     Yes  ...    8735         54
# 3               Agnes Scott College     Yes  ...   19016         59
# 4         Alaska Pacific University     Yes  ...   10922         15
# ..                              ...     ...  ...     ...        ...
# 772         Worcester State College      No  ...    4469         40
# 773               Xavier University     Yes  ...    9189         83
# 774  Xavier University of Louisiana     Yes  ...    8323         49
# 775                 Yale University     Yes  ...   40386         99
# 776    York College of Pennsylvania     Yes  ...    4509         99
#
# [777 rows x 19 columns]

# %%
columnNames = colleges['Unnamed: 0']
columnNames
# Out:
# 0        Abilene Christian University
# 1                  Adelphi University
# 2                      Adrian College
# 3                 Agnes Scott College
# 4           Alaska Pacific University
#                     ...
# 772           Worcester State College
# 773                 Xavier University
# 774    Xavier University of Louisiana
# 775                   Yale University
# 776      York College of Pennsylvania
# Name: Unnamed: 0, Length: 777, dtype: object

# %%
# Remove the column of college's names
col = colleges.loc[:, colleges.columns != 'Unnamed: 0']
col
# Out:
#     Private   Apps  Accept  Enroll  ...  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 0       Yes   1660    1232     721  ...       18.1           12    7041         60
# 1       Yes   2186    1924     512  ...       12.2           16   10527         56
# 2       Yes   1428    1097     336  ...       12.9           30    8735         54
# 3       Yes    417     349     137  ...        7.7           37   19016         59
# 4       Yes    193     146      55  ...       11.9            2   10922         15
# ..      ...    ...     ...     ...  ...        ...          ...     ...        ...
# 772      No   2197    1515     543  ...       21.0           14    4469         40
# 773     Yes   1959    1805     695  ...       13.3           31    9189         83
# 774     Yes   2097    1915     695  ...       14.4           20    8323         49
# 775     Yes  10705    2453    1317  ...        5.8           49   40386         99
# ...

# %%
# We make a summary of dataset
col.describe()
# Out:
#                Apps        Accept  ...        Expend  Grad.Rate
# count    777.000000    777.000000  ...    777.000000  777.00000
# mean    3001.638353   2018.804376  ...   9660.171171   65.46332
# std     3870.201484   2451.113971  ...   5221.768440   17.17771
# min       81.000000     72.000000  ...   3186.000000   10.00000
# 25%      776.000000    604.000000  ...   6751.000000   53.00000
# 50%     1558.000000   1110.000000  ...   8377.000000   65.00000
# 75%     3624.000000   2424.000000  ...  10830.000000   78.00000
# max    48094.000000  26330.000000  ...  56233.000000  118.00000
#
# [8 rows x 17 columns]

# %%
axes = pd.plotting.scatter_matrix(col.iloc[:, 0:11], alpha=0.2)
plt.figure(figsize=(20,100))

# %%
# Boxplots of Outstate VS Private
# fig1, ax1 = plt.subplots()
# ax1.set_title('Basic Plot')
# ax1.boxplot()
col[['Outstate', 'Private']]
# Out:
#      Outstate Private
# 0        7440     Yes
# 1       12280     Yes
# 2       11250     Yes
# 3       12960     Yes
# 4        7560     Yes
# ..        ...     ...
# 772      6797      No
# 773     11520     Yes
# 774      6900     Yes
# 775     19840     Yes
# 776      4990     Yes
#
# [777 rows x 2 columns]
